# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ### Extract all category names available, store in "cat_names"

# %%
url="https://blackwells.co.uk/bookshop/category/_top"
response = requests.get(url)

# Send an HTTP request to the URL
response = requests.get(url)

# Check if the request was successful (status code 200)

if response.status_code == 200:
    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(response.content, "html.parser")

    # Find all HTML elements that contain developer names
    category = soup.find("ul", attrs= {'class' : 'block-filter__list category-list'})
    # Extract all "li" elements under the found "ul" element
    cat_list = category.find_all("li")

    # Create a list to store the text content of each "li" element
    book_cats = [cat.text.strip() for cat in cat_list]

    # Print the list of "li" texts
    print(book_cats)
else:
    print(f"Failed to retrieve content. Status Code: {response.status_code}")
# Out:
# ['Art and Design', 'Biography', 'Business, Economics and Law', "Children's", 'Computing', 'Crime and Thrillers', 'Education', 'Fiction', 'Food and Drink', 'Graphic Novels', 'Health and Wellbeing', 'History', 'Home and Garden', 'Languages and Reference', 'Literature and Poetry', 'Medical and Nursing', 'Music', 'Philosophy and Religion', 'Politics', 'Science and Nature', 'SF, Fantasy & Horror', 'Social Sciences', 'Sports and Hobbies', 'Stage and Screen', 'Stationery and Gift', 'Technology and Transport', 'Teen and YA', 'Travel']

# %%
#Adjust name to align with url structure:
for i in range(len(book_cats)):
    if book_cats[i] == 'Crime and Thrillers':
        book_cats[i] = 'Crime'
    elif book_cats[i] == 'Science and Nature':
        book_cats[i] = 'Science'
    elif book_cats[i] == 'Business,Economics and Law':
        book_cats[i] = 'Business'
    elif book_cats[i] == 'Health and Wellbeing':
        book_cats[i] = 'Health'
    elif book_cats[i] == 'Languages and Reference':
        book_cats[i] = 'Languages'
    elif book_cats[i] == 'Literature and Poetry':
        book_cats[i] = 'Literature'
    elif book_cats[i] == 'Medical and Nursing':
        book_cats[i] = 'Medical'
    elif book_cats[i] == 'Philosophy and Religion':
        book_cats[i] = 'Philosophy'
    elif book_cats[i] == 'Sports and Hobbies':
        book_cats[i] = 'Sports'
    elif book_cats[i] == 'Stage and Screen':
        book_cats[i] = 'Stage'
    elif book_cats[i] == 'Technology and Transport':
        book_cats[i] = 'Technology'
# Display the updated list
print(book_cats)
# Out:
# ['Art and Design', 'Biography', 'Business, Economics and Law', "Children's", 'Computing', 'Crime', 'Education', 'Fiction', 'Food and Drink', 'Graphic Novels', 'Health', 'History', 'Home and Garden', 'Languages', 'Literature', 'Medical', 'Music', 'Philosophy', 'Politics', 'Science', 'SF, Fantasy & Horror', 'Social Sciences', 'Sports', 'Stage', 'Stationery and Gift', 'Technology', 'Teen and YA', 'Travel']

# %%
# Store in csv:

import csv

# Specify the file path for the CSV file
csv_file_path = "book_cats.csv"

# Open the CSV file in write mode
with open(csv_file_path, mode='w', newline='') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the header (if needed)
    # csv_writer.writerow(["Category Names"])

    # Write the data
    csv_writer.writerow(book_cats)

print(f"Category names have been exported to {csv_file_path}")
# Out:
# Category names have been exported to book_cats.csv

# %% [markdown]
# ### Store best selling list per category

# %% [markdown]
# #### try 1 case

# %%
 # Construct URL for each category
book_cats_processed = [name.lower().replace(" ", "").replace("'", "") for name in book_cats]
category_name=book_cats_processed[0]
category_url = f"https://blackwells.co.uk/bookshop/category/_{category_name.strip().lower()}?offset=0&maxhits=60&sortValue=Bestselling"
category_response = requests.get(category_url)

if category_response.status_code == 200:
    category_soup = BeautifulSoup(category_response.content, "html.parser")
    best_sellers = category_soup.find_all("ul", class_='search-result__list')
    
    for ul_element in best_sellers:
        li_elements = ul_element.find_all("li")
        recommended_list = []
        
        # Loop through each 'li' element
        for item in li_elements[:50]:
            # Find the 'h4' element
            h4_element = item.find("h4")
            if h4_element:
                
                # Find the 'a' element with class 'product-name' inside 'h4'
                product_name_element = h4_element.find("a", class_="product-name")
                product_name = product_name_element.text.strip() if product_name_element else "N/A"
                
                # Find the 'div' element with class 'product-picture'
                product_picture_element = item.find("div", class_="product-picture")
                # Find the 'img' element inside 'product-picture'
                img_element = product_picture_element.find("img") if product_picture_element else None
                product_image = img_element["src"] if img_element and "src" in img_element.attrs else "N/A"
                
                # Find the 'p' element with class 'product-author'
                author_element = item.find("p", class_="product-author")
                author = author_element.text.strip() if author_element else "N/A"
 
                # Find the 'li' element with class 'product-price--current'
                price_element = item.find("li", class_="product-price--current")
                price = price_element.text.strip() if price_element else "N/A"
                
                # Append the extracted data to the recommended_list
                recommended_list.append({"Category":category_name,"Image": product_image, "Title": product_name, "Author": author, "Price": price})
        
        # Print or use the recommended_list here
        print(pd.DataFrame(recommended_list))
        
else:
    print(f"Failed to fetch data for category: {category_name}")
print(len(recommended_list))
# Out:
#                                 Image                               Title  \
# 0   /jacket/200x200/9781849947671.jpg                           Sea Pools
# 1   /jacket/200x200/9781855145870.jpg  David Hockney - Normandy Portra...
# 2   /jacket/200x200/9781954928008.jpg               The Gorillaz Art Book
# 3   /jacket/200x200/9781937986742.jpg  Photographer's Guide to the Nik...
# 4   /jacket/200x200/9781788842389.jpg                  The Rolling Stones
# 5   /jacket/200x200/9780770435219.jpg          Urban Watercolor Sketching
# 6   /jacket/200x200/9781032324142.jpg                Experiencing Accents
# 7   /jacket/200x200/9781350143111.jpg  The Intersection of Fashion and...
# 8   /jacket/200x200/9781848220560.jpg                  Leonora Carrington
# 9   /jacket/200x200/9780760382806.jpg                     Made to Measure
# 10  /jacket/200x200/9781912235575.jpg                         Ghost Trees
# 11  /jacket/200x200/9781523519101.jpg    Audubon Engagement Calendar 2024
# 12  /jacket/200x200/9783836507462.jpg                   Wassily Kandinsky
# 13  /jacket/200x200/9781914236228.jpg  Salena Godden - Pessimism Is fo...
# 14  /jacket/200x200/9780141995311.jpg  140 Artists' Ideas for Planet E...
# 15  /jacket/200x200/9781858947075.jpg                    Mid-Century Type
# 16  /jacket/200x200/9780136746911.jpg  100 Things Every Designer Needs...
# 17  /jacket/200x200/9781789940923.jpg                           Wild Clay
# 18  /jacket/200x200/9781781577820.jpg                 How to Be an Artist
# 19  /jacket/200x200/9784756253941.jpg           Fashion Illustration Book
# 20  /jacket/200x200/9781907896972.jpg  Translations from Drawing to Bu...
# 21  /jacket/200x200/9782878682793.jpg                     Rome Sketchbook
# 22  /jacket/200x200/9781804173862.jpg  Alphonse Mucha Wall Calendar 20...
#
#                      Author   Price
# 0           Chris Romer-Lee  35,54€
# 1   David Hockney, Natio...  22,15€
# 2    Jamie Hewlett (artist)  87,16€
# 3       White, Alexander S.  32,26€
# 4   Acc Art Books Ltd (C...  63,87€
# 5        Felix Scheinberger  21,03€
# 6   Philip Thompson (aut...  38,37€
# 7     Kate Annett-Hitchcock  26,85€
# 8   Susan L. Aberth, Leo...  35,03€
# 9           Elisalex Jewell  24,30€
# 10              Bob Gilbert  15,41€
# 11  National Audubon Soc...     N/A
# 12  Hajo Düchting, Wassi...  18,29€
# 13            Salena Godden  28,96€
# 14  Hans Ulrich Obrist (...  14,04€
# 15               David Jury  40,65€
# 16         Susan Weinschenk  26,70€
# 17  Matt Levy, Takuro Sh...  35,05€
# 18              Jerry Saltz  13,33€
# 19                   Tanaka  25,86€
# 20              Robin Evans  36,58€
# 21  Fabrice Moireau (ill...  29,03€
# 22  Flame Tree Studio (c...     N/A
# 23

# %% [markdown]
# ### Loop through all category

# %%
 # Construct URL for each category
#book_cats_processed = [name.lower().replace(" ", "") for name in book_cats]
all_results=[]
for category_name in book_cats:
    if category_name == "SF, Fantasy & Horror":
        category_processed = "sf"
    elif category_name == "Social Sciences":
        category_processed = "socsci"
    else:
        category_processed = category_name.lower().replace(" ", "").replace("'", "")
        category_url = f"https://blackwells.co.uk/bookshop/category/_{category_processed}?offset=0&maxhits=60&sortValue=Bestselling"
        category_response = requests.get(category_url)

        if category_response.status_code == 200:
            category_soup = BeautifulSoup(category_response.content, "html.parser")
            best_sellers = category_soup.find_all("ul", class_='search-result__list')

            recommended_list = []

            # Loop through each 'li' element
            for ul_element in best_sellers:
                li_elements = ul_element.find_all("li")
                
                for item in li_elements[:50]:
                    # Find the 'h4' element
                    h4_element = item.find("h4")
                    if h4_element:
                        # Find the 'a' element with class 'product-name' inside 'h4'
                        product_name_element = h4_element.find("a", class_="product-name")
                        product_name = product_name_element.text.strip() if product_name_element else "N/A"

                        # Find the 'div' element with class 'product-picture'
                        product_picture_element = item.find("div", class_="product-picture")
                        # Find the 'img' element inside 'product-picture'
                        img_element = product_picture_element.find("img") if product_picture_element else None
                        product_image = img_element["src"] if img_element and "src" in img_element.attrs else "N/A"

                        # Find the 'p' element with class 'product-author'
                        author_element = item.find("p", class_="product-author")
                        author = author_element.text.strip() if author_element else "N/A"

                        # Find the 'li' element with class 'product-price--current'
                        price_element = item.find("li", class_="product-price--current")
                        price = price_element.text.strip() if price_element else "N/A"

                        # Append the extracted data to the recommended_list
                        recommended_list.append({"Category": category_name, "Image": product_image, "Title": product_name, "Author": author, "Price": price})

            # Print or use the recommended_list here
            all_results.extend(recommended_list)
            print(pd.DataFrame(all_results))
        else:
            print(f"Failed to fetch data for category: {category_name}")

all_bestsellers=pd.DataFrame(all_results)
# Out:
#           Category                              Image  \
# 0   Art and Design  /jacket/200x200/9781849947671.jpg
# 0                            Sea Pools          Chris Romer-Lee  35,54€
# 1   David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3   Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                   The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                 ...                      ...     ...
# 85  Implementing Lean Software Deve...  Mary Poppendieck, Th...  37,15€
# 86                     The Repair Shop  Jayne Dowle (author)...  23,13€
# 87       Articulating Design Decisions              Tom Greever  40,63€
# 88                  MATLAB for Dummies  Jim Sizemore, John M...  26,16€
# 89     Designing With the Mind in Mind             Jeff Johnson  49,76€
#
# [90 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 109           Crime  /jacket/200x200/9780099553106.jpg
# 110           Crime  /jacket/200x200/9781974733965.jpg
# 111           Crime  /jacket/200x200/9780571371044.jpg
# 112           Crime  /jacket/200x200/9781788424233.jpg
# 113           Crime  /jacket/200x200/9780008164898.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 109                            Triptych          Karin Slaughter  13,53€
# 110                    Sakamoto Days. 4              Yuto Suzuki  11,48€
# 111                    The Glass Pearls       Emeric Pressburger  13,62€
# 112                Death and Croissants                Ian Moore  13,53€
# 113                  Cards on the Table          Agatha Christie  13,24€
#
# [114 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 132       Education  /jacket/200x200/9781032269832.jpg
# 133       Education  /jacket/200x200/9781338776942.jpg
# 134       Education  /jacket/200x200/9781338776874.jpg
# 135       Education  /jacket/200x200/9781787754874.jpg
# 136       Education  /jacket/200x200/9781529716221.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 132  Research With International Stu...  Jenna Mittelmeier (e...  45,19€
# 133          Curse of the Shadow Dragon  Tracey West (author)...  11,12€
# 134          Bloom of the Flower Dragon  Tracey West (author)...  10,91€
# 135  The Teacher's Introduction to P...             Clare Truman  21,42€
# 136             Play in the Early Years                Owen, Kay  27,65€
#
# [137 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 155         Fiction  /jacket/200x200/9780715654514.jpg
# 156         Fiction  /jacket/200x200/9780349142104.jpg
# 157         Fiction  /jacket/200x200/9781975372033.jpg
# 158         Fiction  /jacket/200x200/9781473224377.jpg
# 159         Fiction  /jacket/200x200/9781805461005.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 155                 The Spirit Engineer               A. J. West  13,53€
# 156          The Dog Who Dared to Dream  Sun-mi Hwang (author...  13,33€
# 157             Days With My Stepsister  Ghost Mikawa (author...  16,93€
# 158                      Winter's Gifts          Ben Aaronovitch  17,01€
# 159                      The Amber Fury           Natalie Haynes  13,62€
#
# [160 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 175  Food and Drink  /jacket/200x200/9780762480623.jpg
# 176  Food and Drink  /jacket/200x200/9781761500107.jpg
# 177  Food and Drink  /jacket/200x200/9781645678106.jpg
# 178  Food and Drink  /jacket/200x200/9781568364902.jpg
# 179  Food and Drink  /jacket/200x200/9780600633495.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 175             Eddie Muller's Noir Bar             Eddie Muller  22,35€
# 176                        More Is More                Molly Baz  27,17€
# 177               Elegant One-Pan Cakes             Sonali Ghosh  23,13€
# 178  Japanese Kitchen Knives: Essent...  Kate Klippensteen, Y...  29,03€
# 179             200 Slow Cooker Recipes               Sara Lewis  10,76€
#
# [180 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 199  Graphic Novels  /jacket/200x200/9781421569109.jpg
# 200  Graphic Novels  /jacket/200x200/9781646513758.jpg
# 201  Graphic Novels  /jacket/200x200/9781787332010.jpg
# 202  Graphic Novels  /jacket/200x200/9781444958058.jpg
# 203  Graphic Novels  /jacket/200x200/9781444004878.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 199                          Monster. 5            Naoki Urasawa  16,84€
# 200          Attack on Titan Omnibus. 2           Hajime Isayama  21,49€
# 201                   Footnotes in Gaza                Joe Sacco  27,85€
# 202  Bumble & Snug and the Excited U...             Mark Bradley  12,05€
# 203                   Asterix Omnibus 4         Goscinny, Uderzo  17,72€
#
# [204 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 219          Health  /jacket/200x200/9781398508729.jpg
# 220          Health  /jacket/200x200/9780749912468.jpg
# 221          Health  /jacket/200x200/9781649630728.jpg
# 222          Health  /jacket/200x200/9781849013208.jpg
# 223          Health  /jacket/200x200/9781847943842.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 219                   It's Not Just You                Tori Tsui  17,43€
# 220                Yesterday's Children            Jenny Cockell  17,01€
# 221                   A Life of Meaning             James Hollis  19,20€
# 222  The Compassionate Mind Approach...  Deborah Lee, Sophie ...  17,68€
# 223                 The Perfection Trap            Thomas Curran  23,62€
#
# [224 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 240         History  /jacket/200x200/9781913107024.jpg
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 282  The Bilingual Brain and What It...             Albert Costa  15,15€
# 283  The Colossal Book of Amazing Fa...            Nigel Henbest  18,68€
# 284   Life Elementary 2E, With App Code  John Hughes, Helen S...  45,33€
# 285                 Unfinished Business            Robin Johnson  23,85€
# 286             Advanced Grammar in Use           Martin Hewings  36,38€
#
# [287 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 306      Literature  /jacket/200x200/9781907903571.jpg
# 307      Literature  /jacket/200x200/9781787332010.jpg
# 308      Literature  /jacket/200x200/9781841598307.jpg
# 309      Literature  /jacket/200x200/9781785304446.jpg
# 310      Literature  /jacket/200x200/9780199536719.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 306                          I Remember  Joe Brainard (author...  19,22€
# 307                   Footnotes in Gaza                Joe Sacco  27,85€
# 308                        Uyghur Poems  Aziz Isa Elkun (tran...  15,91€
# 309                                Life           Donna Ashworth  14,26€
# 310                     The Dead Secret  Wilkie Collins, Ira ...  13,45€
#
# [311 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 327         Medical  /jacket/200x200/9781849013208.jpg
# 328         Medical  /jacket/200x200/9780702084010.jpg
# 329         Medical  /jacket/200x200/9780241600498.jpg
# 330         Medical  /jacket/200x200/9780702055706.jpg
# 331         Medical  /jacket/200x200/9781787754874.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 327  The Compassionate Mind Approach...  Deborah Lee, Sophie ...  17,68€
# 328  Essential Calculations for Vete...  Terry Lake, Nicola G...  44,50€
# 329             The Complete Human Body            Alice Roberts  32,78€
# 330  The Midwives' Guide to Key Medi...  Linda Wylie, Helen B...  34,42€
# 331  The Teacher's Introduction to P...             Clare Truman  21,42€
#
# [332 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 352           Music  /jacket/200x200/9781616770150.jpg
# 353           Music  /jacket/200x200/9780193381407.jpg
# 354           Music  /jacket/200x200/9780193727847.jpg
# 355           Music  /jacket/200x200/9780062319432.jpg
# 356           Music  /jacket/200x200/9781738581702.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 352  Pretime Piano Christmas - Prime...  Nancy Faber (other),...  12,22€
# 353  Enjoy Playing Guitar Tutor Book...         Debbie Cracknell     N/A
# 354                        Piano Time 1  Pauline Hall (compos...     N/A
# 355                           Can I Say  Travis Barker, Gavin...  20,93€
# 356            Get on the Rollercoaster  Karamdeep Sahota (au...  26,69€
#
# [357 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 375      Philosophy  /jacket/200x200/9780715654514.jpg
# 376      Philosophy  /jacket/200x200/9780199236954.jpg
# 377      Philosophy  /jacket/200x200/9780856686092.jpg
# 378      Philosophy  /jacket/200x200/9780281068630.jpg
# 379      Philosophy  /jacket/200x200/9781529112184.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 375                 The Spirit Engineer               A. J. West  13,53€
# 376                          Witchcraft          Malcolm Gaskill  13,45€
# 377                  Euripides: Bacchae  R. A. S. Seaford (ed...  33,15€
# 378                 1 & 2 Peter & Judah  N. T. Wright (author...  10,92€
# 379                Metaphysical Animals  Clare Mac Cumhaill, ...  15,15€
#
# [380 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 533  Tales of Brave and Brilliant Gi...  Susanna Davidson (au...  10,70€
# 534                 The Godhead Complex            James Dashner  22,47€
#
# [535 rows x 5 columns]
#            Category                              Image  \
# 0    Art and Design  /jacket/200x200/9781849947671.jpg
# 1    Art and Design  /jacket/200x200/9781855145870.jpg
# 2    Art and Design  /jacket/200x200/9781954928008.jpg
# 3    Art and Design  /jacket/200x200/9781937986742.jpg
# 4    Art and Design  /jacket/200x200/9781788842389.jpg
# ..              ...                                ...
# 552          Travel  /jacket/200x200/9781782750758.jpg
# 553          Travel  /jacket/200x200/9788895218199.jpg
# 554          Travel  /jacket/200x200/9780674275607.jpg
# 555          Travel  /jacket/200x200/9781839058554.jpg
# 556          Travel  /jacket/200x200/9781839057656.jpg
#
#                                   Title                   Author   Price
# 0                             Sea Pools          Chris Romer-Lee  35,54€
# 1    David Hockney - Normandy Portra...  David Hockney, Natio...  22,15€
# 2                 The Gorillaz Art Book   Jamie Hewlett (artist)  87,16€
# 3    Photographer's Guide to the Nik...      White, Alexander S.  32,26€
# 4                    The Rolling Stones  Acc Art Books Ltd (C...  63,87€
# ..                                  ...                      ...     ...
# 552          Madeira Tour and Trail Map              David Brawn     N/A
# 553  Puglia in Cucina: The Flavours ...  William Dello Russo ...  27,49€
# 554  Travels With Tocqueville Beyond...          Jeremy Jennings  34,78€
# 555         The Rough Guide to Thailand   Paul Gray, Thomas Bird  21,74€
# 556  The Mini Rough Guide to Lanzaro...  Pam Barrett (author)...  11,88€
#
# [557 rows x 5 columns]

# %%
# Store in csv:

import csv

# Specify the file path for the CSV file
csv_file_path = "all_bestsellers.csv"

# Open the CSV file in write mode
with open(csv_file_path, mode='w', newline='') as csv_file:
    # Create a CSV writer
    csv_writer = csv.writer(csv_file)

    # Write the data
    csv_writer.writerow(all_bestsellers)

print(f"Category names have been exported to {csv_file_path}")
# Out:
# Category names have been exported to all_bestsellers.csv

# %%
len(all_results)
# Out:
# 557

# %%
book_cats
# Out:
# ['Art and Design',
#  'Biography',
#  'Business, Economics and Law',
#  "Children's",
#  'Computing',
#  'Crime',
#  'Education',
#  'Fiction',
#  'Food and Drink',
#  'Graphic Novels',
#  'Health',
#  'History',
#  'Home and Garden',
#  'Languages',
#  'Literature',
#  'Medical',
#  'Music',
#  'Philosophy',
#  'Politics',
#  'Science',
#  'SF, Fantasy & Horror',
#  'Social Sciences',
#  'Sports',
#  'Stage',
#  'Stationery and Gift',
#  'Technology',
#  'Teen and YA',
#  'Travel']

# %%
len(book_cats_processed)
# Out:
# 28

# %%
all_bestsellers["Category"].value_counts()
# Out:
# Children's             25
# Music                  25
# Literature             24
# Teen and YA            24
# Crime                  24
# Stationery and Gift    24
# Graphic Novels         24
# Art and Design         23
# Technology             23
# Philosophy             23
# Languages              23
# Fiction                23
# Education              23
# Sports                 22
# Travel                 22
# Biography              21
# History                21
# Medical                21
# Science                21
# Stage                  21
# Computing              21
# Health                 20
# Food and Drink         20
# Politics               20
# Home and Garden        19
# Name: Category, dtype: int64
